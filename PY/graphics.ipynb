# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")
# %matplotlib inline

# %%
def plott(res, sc_num, metrica, col, xlim_from, xlim_to):
    plt.figure(figsize =  (6, 7))

    sns.boxplot(x = metrica, y = 'dist', 
                data = res[res['col'] == col], 
                palette = "colorblind",
                hue = 'estimator')

    plt.grid(alpha = 0.5, linestyle = '--', linewidth = 0.6)
    plt.title("Scen." + str(sc_num) + ", " + str(metrica) + " by " + str(col) + ", 100cy.")
    plt.tight_layout()
    plt.xlim(xlim_from, xlim_to)
    plt.show()

# %% [markdown]
# # Rel_bias

# %%
relb_scen1_100cy = pd.read_csv('/Users/ash/Desktop/MICE/PY/fin_res_csv/relb_scen1_100cy.csv')
plott(relb_scen1_100cy, 'rel_bias', 'X', -0.18, 0.1)

# %%
relb_scen1_100cy
# Out:
#            dist estimator  col  rel_bias
# 0          norm    ice_rf    X -0.001641
# 1          norm    ice_rf  X^2 -0.004900
# 2          norm   mice_rf    X -0.002148
# 3          norm   mice_rf  X^2 -0.006219
# 4          norm       knn    X -0.002253
# ...         ...       ...  ...       ...
# 6395  norm_mix2   mice_rf  X^2  0.000891
# 6396  norm_mix2       knn    X  0.000256
# 6397  norm_mix2       knn  X^2  0.001503
# 6398  norm_mix2   mice_br    X  0.024260
# 6399  norm_mix2   mice_br  X^2 -0.399177
#
# [6400 rows x 4 columns]

# %%
plott(relb_scen1_100cy, 'rel_bias', 'X^2', -0.18, 0.1)

# %%
rel_bias_scen2 = pd.read_csv('/Users/ash/rel_bias_scen2.csv')
plott(rel_bias_scen2, 2, 'rel_bias', 'X', -0.1, 0.2)

# %%
miceBR_relb_scen1_100cy = pd.read_csv('/Users/ash/Desktop/MICE/PY/fin_res_csv/miceBR_rel_bias_scen1.csv')
plott(miceBR_relb_scen1_100cy, 1, 'rel_bias', 'X', -0.18, 1)

# %%
plott(miceBR_relb_scen1_100cy, 1, 'rel_bias', 'X^2', -0.5, 0.3)

# %%
miceBR_relb_scen2 = pd.read_csv('/Users/ash/Desktop/MICE/PY/fin_res_csv/miceBR_rel_bias_scen2.csv')
plott(miceBR_relb_scen2, 2, 'rel_bias', 'X', -0.2, 0.2)

# %%
plott(miceBR_relb_scen2, 2, 'rel_bias', 'X^2', -0.2, 0.2)

# %%
#all bad
miceBR_relb_scen3 = pd.read_csv('/Users/ash/Desktop/MICE/PY/fin_res_csv/miceBR_rel_bias_scen3.csv')
plott(miceBR_relb_scen3, 3, 'rel_bias', 'XZ', -0.2, 0.16)

# %%
miceBR_relb_scen4 = pd.read_csv('/Users/ash/Desktop/MICE/PY/fin_res_csv/miceBR_rel_bias_scen4.csv')
plott(miceBR_relb_scen4, 4, 'rel_bias', 'X', -0.16, 0.16)

# %%
miceBR_relb_scen4 = pd.read_csv('/Users/ash/Desktop/MICE/PY/fin_res_csv/miceBR_rel_bias_scen4.csv')
plott(miceBR_relb_scen4, 4, 'rel_bias', 'XZ', -0.16, 0.16)
